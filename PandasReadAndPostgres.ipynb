# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\DIKA\\DikaPhyton\\survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('C:\\Users\\DIKA\\DikaPhyton\\survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
filt = (df['Country'] == 'Serbia')
serbia_df = df.loc[filt]
serbia_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 141                 I am a developer by profession      Yes  23.0         16
# 831                 I am a developer by profession       No  45.0         12
# 851                 I am a developer by profession      Yes   NaN         14
# 1686        I am a student who is learning to code      Yes  24.0         17
# 1945                I am a developer by profession      Yes  41.0          8
#
#            CompFreq  CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 141             NaN        NaN            NaN  Serbia                   NaN
# 831         Monthly        NaN            NaN  Serbia         Serbian dinar
# 851          Yearly   150000.0       150000.0  Serbia  United States dollar
# 1686            NaN        NaN            NaN  Serbia                   NaN
# 1945        Monthly     5000.0        64860.0  Serbia         European Euro
#
# ...

# %%
serbia_df.to_csv('C:\\Users\\DIKA\\DikaPhyton\\modified.csv')

# %%
serbia_df.to_csv('C:\\Users\\DIKA\\DikaPhyton\\modified.tsv', sep='\t')

# %%
serbia_df.to_excel('C:\\Users\\DIKA\\DikaPhyton\\modified.xlsx')

# %%
test = pd.read_excel('C:\\Users\\DIKA\\DikaPhyton\\modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 141                 I am a developer by profession      Yes  23.0         16
# 831                 I am a developer by profession       No  45.0         12
# 851                 I am a developer by profession      Yes   NaN         14
# 1686        I am a student who is learning to code      Yes  24.0         17
# 1945                I am a developer by profession      Yes  41.0          8
#
#            CompFreq  CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 141             NaN        NaN            NaN  Serbia                   NaN
# 831         Monthly        NaN            NaN  Serbia         Serbian dinar
# 851          Yearly   150000.0       150000.0  Serbia  United States dollar
# 1686            NaN        NaN            NaN  Serbia                   NaN
# 1945        Monthly     5000.0        64860.0  Serbia         European Euro
#
# ...

# %%
serbia_df.to_json('C:\\Users\\DIKA\\DikaPhyton\\modified.json', orient='records', lines=True)

# %%
test = pd.read_json('C:\\Users\\DIKA\\DikaPhyton\\modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 0          I am a developer by profession      Yes  23.0         16     None
# 1          I am a developer by profession       No  45.0         12  Monthly
# 2          I am a developer by profession      Yes   NaN         14   Yearly
# 3  I am a student who is learning to code      Yes  24.0         17     None
# 4          I am a developer by profession      Yes  41.0          8  Monthly
#
#    CompTotal  ConvertedComp Country          CurrencyDesc CurrencySymbol  \
# 0        NaN            NaN  Serbia                  None           None
# 1        NaN            NaN  Serbia         Serbian dinar            RSD
# 2   150000.0       150000.0  Serbia  United States dollar            USD
# 3        NaN            NaN  Serbia                  None           None
# 4     5000.0        64860.0  Serbia         European Euro            EUR
#
#                               DatabaseDesireNextYear  \
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:Dika2161877@localhost:5432/PrvaBaza')

# %%
serbia_df.to_sql('prvatable', engine, if_exists='replace')

# %%
sql_df = pd.read_sql('prvatable', engine, index_col='Respondent')

# %%
sql_df.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 141                 I am a developer by profession      Yes  23.0         16
# 831                 I am a developer by profession       No  45.0         12
# 851                 I am a developer by profession      Yes   NaN         14
# 1686        I am a student who is learning to code      Yes  24.0         17
# 1945                I am a developer by profession      Yes  41.0          8
#
#            CompFreq  CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 141            None        NaN            NaN  Serbia                  None
# 831         Monthly        NaN            NaN  Serbia         Serbian dinar
# 851          Yearly   150000.0       150000.0  Serbia  United States dollar
# 1686           None        NaN            NaN  Serbia                  None
# 1945        Monthly     5000.0        64860.0  Serbia         European Euro
#
# ...

# %%
sql_dff = pd.read_sql_query('Select * from prvatable', engine, index_col='Respondent')

# %%
sql_dff.head()
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 141                 I am a developer by profession      Yes  23.0         16
# 831                 I am a developer by profession       No  45.0         12
# 851                 I am a developer by profession      Yes   NaN         14
# 1686        I am a student who is learning to code      Yes  24.0         17
# 1945                I am a developer by profession      Yes  41.0          8
#
#            CompFreq  CompTotal  ConvertedComp Country          CurrencyDesc  \
# Respondent
# 141            None        NaN            NaN  Serbia                  None
# 831         Monthly        NaN            NaN  Serbia         Serbian dinar
# 851          Yearly   150000.0       150000.0  Serbia  United States dollar
# 1686           None        NaN            NaN  Serbia                  None
# 1945        Monthly     5000.0        64860.0  Serbia         European Euro
#
# ...
